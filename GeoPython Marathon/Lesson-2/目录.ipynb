# %% [markdown]
# 1.	变量
#
# 2.	常见数据类型
#
# 3.	可变与不可变类型
#
# 4.	运算符
#
# 5.	列表和元组
#
# 6.	条件表达式与布尔值
#
# 7.	循环结构和循环控制语句
#
# 8.	函数
#
# 9.	字典
#
# 10.	类与对象、属性、方法、构造函数
#
# 11.	模块与包.
#
# 12. 科学计算包Numpy
#
# 13. 文件操作
#
# 14. 矩阵操作
